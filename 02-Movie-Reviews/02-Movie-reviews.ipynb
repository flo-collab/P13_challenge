# %% [markdown]
# # Movie Reviews

# %%
import pandas as pd

data = pd.read_csv("reviews.csv")

data.head()
# Out:
#   target                                            reviews
# 0    neg  plot : two teen couples go to a church party ,...
# 1    neg  the happy bastard's quick movie review \ndamn ...
# 2    neg  it is movies like these that make a jaded movi...
# 3    neg   " quest for camelot " is warner bros . ' firs...
# 4    neg  synopsis : a mentally unstable man undergoing ...

# %% [markdown]
# The dataset is made up of positive and negative movie reviews.

# %% [markdown]
# ## Preprocessing
#
# 👇 Remove punctuation and lower case the text.

# %%
import re
def remove_punctuation(oldtext):
    newtext = re.sub(r'[^A-Za-z]+', ' ', oldtext)
    return newtext

data['clean'] = data['reviews'].apply(remove_punctuation)
data['clean'] = data['clean'].str.lower()
data
# Out:
#      target                                            reviews  \
# 0       neg  plot : two teen couples go to a church party ,...
# 1       neg  the happy bastard's quick movie review \ndamn ...
# 2       neg  it is movies like these that make a jaded movi...
# 3       neg   " quest for camelot " is warner bros . ' firs...
# 4       neg  synopsis : a mentally unstable man undergoing ...
# ...     ...                                                ...
# 1995    pos  wow ! what a movie . \nit's everything a movie...
# 1996    pos  richard gere can be a commanding actor , but h...
# 1997    pos  glory--starring matthew broderick , denzel was...
# 1998    pos  steven spielberg's second epic film on world w...
# 1999    pos  truman ( " true-man " ) burbank is the perfect...
#
#                                                   clean
# 0     plot two teen couples go to a church party dri...
# 1     the happy bastard s quick movie review damn th...
# 2     it is movies like these that make a jaded movi...
# 3      quest for camelot is warner bros first featur...
# 4     synopsis a mentally unstable man undergoing ps...
# ...                                                 ...
# 1995  wow what a movie it s everything a movie can b...
# 1996  richard gere can be a commanding actor but he ...
# 1997  glory starring matthew broderick denzel washin...
# 1998  steven spielberg s second epic film on world w...
# 1999  truman true man burbank is the perfect name fo...
#
# [2000 rows x 3 columns]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fuetu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Bag-of-Words modelling

# %% [markdown]
# 👇 Using `cross_validate`, score a Multinomial Naive Bayes model trained on a Bag-of-Word representation of the texts.

# %%
def filter_stopword(string:str):
    temp = string.split(' ')
    out=[]
    for w in temp:
        if w not in nltk.corpus.stopwords.words('english'):
            #print(w)
            out.append(w)
    return ' '.join(out)

# %%
data['clean'] = data['clean'].apply(filter_stopword)

# %% [markdown]
# ## N-gram modelling

# %% [markdown]
# 👇 Using `cross_validate`, score a Multinomial Naive Bayes model trained on a 2-gram Bag-of-Word representation of the texts.

# %%
data['clean'].apply(nltk.bigrams)
# Out:
# 0       <generator object bigrams at 0x000001460A68BD60>
# 1       <generator object bigrams at 0x000001460A6280B0>
# 2       <generator object bigrams at 0x000001460A628190>
# 3       <generator object bigrams at 0x000001460A628200>
# 4       <generator object bigrams at 0x000001460A628270>
#                               ...
# 1995    <generator object bigrams at 0x000001460A7D86D0>
# 1996    <generator object bigrams at 0x000001460A7D8740>
# 1997    <generator object bigrams at 0x000001460A7D87B0>
# 1998    <generator object bigrams at 0x000001460A7D8820>
# 1999    <generator object bigrams at 0x000001460A7D8890>
# Name: clean, Length: 2000, dtype: object

# %%
list(nltk.bigrams('To be or not to be'.split()))
# Out:
# [('To', 'be'), ('be', 'or'), ('or', 'not'), ('not', 'to'), ('to', 'be')]

# %%
# def make_bigram(string=str):
#     return list(nltk.bigrams(string.split()))
# data['clean'] = data['clean'].apply(make_bigram)
# data

# %%
data
# Out:
#      target                                            reviews  \
# 0       neg  plot : two teen couples go to a church party ,...
# 1       neg  the happy bastard's quick movie review \ndamn ...
# 2       neg  it is movies like these that make a jaded movi...
# 3       neg   " quest for camelot " is warner bros . ' firs...
# 4       neg  synopsis : a mentally unstable man undergoing ...
# ...     ...                                                ...
# 1995    pos  wow ! what a movie . \nit's everything a movie...
# 1996    pos  richard gere can be a commanding actor , but h...
# 1997    pos  glory--starring matthew broderick , denzel was...
# 1998    pos  steven spielberg's second epic film on world w...
# 1999    pos  truman ( " true-man " ) burbank is the perfect...
#
#                                                   clean
# 0     plot two teen couples go church party drink dr...
# 1     happy bastard quick movie review damn k bug go...
# 2     movies like make jaded movie viewer thankful i...
# 3      quest camelot warner bros first feature lengt...
# 4     synopsis mentally unstable man undergoing psyc...
# ...                                                 ...
# 1995  wow movie everything movie funny dramatic inte...
# 1996  richard gere commanding actor always great fil...
# 1997  glory starring matthew broderick denzel washin...
# 1998  steven spielberg second epic film world war ii...
# 1999  truman true man burbank perfect name jim carre...
#
# [2000 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
matrix = CountVectorizer(ngram_range=(2,2)
 
# to use bigrams ngram_range=(2,2)
                           ,stop_words='english'
                           )

# %%
X_bi = matrix.fit_transform(data['clean'])

# %%
data.loc[data['target'] == 'pos', "num_target"] = int(1)
data.loc[data['target'] == 'neg', "num_target"] = int(0)
data["num_target"] = data["num_target"].astype(int)

# %%
y_bow = data["num_target"]

# %%
X_bi.shape
# Out:
# (2000, 484721)

# %% [markdown]
# ⚠️ Please push the exercise once you are done 🙃
#
# ## 🏁

# %%
matrix.get_feature_names()
# Out:
# ['aa meetings',
#  'aaa minor',
#  'aaa team',
#  'aaaaaaaaah critique',
#  'aaaaaaaaah day',
#  'aaaaaaaahhhh plot',
#  'aaaaaah film',
#  'aaaahhhs wows',
#  'aahs pixar',
#  'aaliyah impressive',
#  'aaliyah shabby',
#  'aaliyah trish',
#  'aalyah enchanting',
#  'aalyah mafia',
#  'aalyah magical',
#  'aamir khan',
#  'aardman animation',
#  'aaron chuck',
#  'aaron convincing',
#  'aaron determined',
#  'aaron eckhart',
#  'aaron edward',
#  'aaron gets',
#  'aaron moor',
#  'aaron pearl',
#  'aaron sandra',
#  'aaron schneider',
#  'aaron spelling',
#  'aaron steve',
#  'aaron williams',
#  'aatish director',
#  'ab using',
#  'aback honesty',
#  'aback unusual',
#  'abandon alien',
#  'abandon conviction',
#  'abandon creation',
#  'abandon depth',
#  'abandon despite',
#  'abandon educating',
#  'abandon farm',
#  'abandon figured',
#  'abandon film',
#  'abandon final',
#  'abandon friends',
#  'abandon goal',
#  'abandon left',
#  'abandon moment',
#  'abandon naturally',
#  'abandon noise',
#  'abandon preview',
#  'abandon principle',
#  'abandon rejecting',
#  'abandon rescue',
#  'abandon ship',
#  'abandon sure',
#  'abandon trying',
#  'abandon unique',
#  'abandoned adopted',
#  'abandoned air',
#  'abandoned altar',
#  'abandoned beaten',
#  'abandoned boredom',
#  'abandoned born',
#  'abandoned building',
#  'abandoned buildings',
#  'abandoned child',
#  'abandoned church',
#  'abandoned cruiser',
#  'abandoned danvers',
#  'abandoned david',
#  'abandoned father',
#  'abandoned girlfriend',
#  'abandoned highway',
#  'abandoned house',
#  'abandoned left',
#  'abandoned literally',
#  'abandoned lose',
#  'abandoned lunatic',
#  'abandoned luther',
#  'abandoned mansion',
#  'abandoned mining',
#  'abandoned novalee',
#  'abandoned owner',
#  'abandoned placed',
#  'abandoned planet',
#  'abandoned prison',
#  'abandoned russian',
#  'abandoned scrutinize',
#  'abandoned sealed',
#  'abandoned segments',
#  'abandoned shed',
#  'abandoned signature',
#  'abandoned singer',
#  'abandoned spaceship',
#  'abandoned spouses',
#  'abandoned steelworks',
#  'abandoned theater',
#  'abandoned throws',
#  'abandoned warehouse',
#  'abandoned wing',
#  'abandoning facial',
#  'abandoning project',
#  'abandonment alcoholic',
#  'abandonment hope',
#  'abandonment paradise',
#  'abandonment source',
#  'abandons angry',
#  'abandons climactic',
#  'abandons english',
#  'abandons hang',
#  'abandons maroon',
#  'abandons old',
#  'abandons planet',
#  'abandons political',
#  'abating time',
#  'abba music',
#  'abba tunes',
#  'abbe coulmier',
#  'abbe handsome',
#  'abbe lusts',
#  'abberation continues',
#  'abberline johnny',
#  'abberline widower',
#  'abbots circle',
#  'abbott jay',
#  'abbotts eventually',
#  'abbreviated bedhopping',
#  'abby asks',
#  'abby assuming',
#  'abby frances',
#  'abby furthering',
#  'abby knows',
#  'abby kohn',
#  'abby meet',
#  'abby mistakes',
#  'abby nia',
#  'abby olivia',
#  'abby relates',
#  'abby talk',
#  'abby tells',
#  'abby thrown',
#  'abc fox',
#  'abc monday',
#  'abc sabrina',
#  'abc wonderful',
#  'abdomen alien',
#  'abdomen sloppy',
#  'abducted brought',
#  'abducted dr',
#  'abducted mctiernan',
#  'abducted suspected',
#  'abducted tortured',
#  'abductees abducted',
#  'abduction meantime',
#  'abduction save',
#  'abduction scenarios',
#  'abduction scene',
#  'abduction young',
#  'abductions genetic',
#  'abductions sad',
#  'abdul jabbar',
#  'abe handling',
#  'abe lincoln',
#  'abe petrovsky',
#  'abel ferrara',
#  'abel ferrera',
#  'abel prosecutes',
#  'aberdeen able',
#  'aberdeen differences',
#  'aberdeen earlier',
#  'aberdeen half',
#  'aberdeen jean',
#  'aberdeen know',
#  'aberdeen rampling',
#  'aberdeen scotland',
#  'aberdeen sentimental',
#  'aberdeen strives',
#  'aberration film',
#  'aberration incipient',
#  'abetted director',
#  'abetted wonderfully',
#  'abetting criminals',
#  'abetting team',
#  'abhorrence rise',
#  'abhorrent blatantly',
#  'abhorrent feature',
#  'abhorrent picture',
#  'abider tolerance',
#  'abides catholic',
#  'abiding ethnically',
#  'abigail alarming',
#  'abigail consistent',
#  'abigail obsession',
#  'abigail passion',
#  'abigail seizes',
#  'abigail supposedly',
#  'abigail winona',
#  'abiility thanks',
#  'abilities acting',
#  'abilities ahem',
#  'abilities backup',
#  'abilities best',
#  'abilities center',
#  'abilities challenged',
#  'abilities clumsy',
#  'abilities consequently',
#  'abilities create',
#  'abilities differ',
#  'abilities disclosed',
#  'abilities disney',
#  'abilities displays',
#  'abilities emotionally',
#  'abilities end',
#  'abilities evident',
#  'abilities hard',
#  'abilities intelligent',
#  'abilities leads',
#  'abilities lee',
#  'abilities letdown',
#  'abilities likely',
#  'abilities limited',
#  'abilities little',
#  'abilities look',
#  'abilities makes',
#  'abilities mia',
#  'abilities needs',
#  'abilities order',
#  'abilities past',
#  'abilities performances',
#  'abilities reap',
#  'abilities sets',
#  'abilities shine',
#  'abilities spent',
#  'abilities start',
#  'abilities story',
#  'abilities strangers',
#  'abilities support',
#  'abilities tom',
#  'abilities trailer',
#  'abilities tries',
#  'abilities unown',
#  'abilities uses',
#  'abilities usual',
#  'abilities wonderful',
#  'ability actors',
#  'ability actress',
#  'ability age',
#  'ability allow',
#  'ability appreciate',
#  'ability away',
#  'ability blow',
#  'ability bring',
#  'ability carry',
#  'ability catherine',
#  'ability challenge',
#  'ability choose',
#  'ability chuck',
#  'ability cliche',
#  'ability comparable',
#  'ability conceive',
#  'ability control',
#  'ability convey',
#  'ability create',
#  'ability daphne',
#  'ability decent',
#  'ability different',
#  'ability direct',
#  'ability disappointed',
#  'ability discern',
#  'ability drama',
#  'ability echo',
#  'ability enhance',
#  'ability enjoyed',
#  'ability enraptured',
#  'ability entertain',
#  'ability establish',
#  'ability exception',
#  'ability excursions',
#  'ability experience',
#  'ability extract',
#  'ability far',
#  'ability fast',
#  'ability fly',
#  'ability fold',
#  'ability forge',
#  'ability gain',
#  'ability going',
#  'ability got',
#  'ability handle',
#  'ability heal',
#  'ability hollow',
#  'ability hot',
#  'ability impress',
#  'ability invasion',
#  'ability isabella',
#  'ability jaw',
#  'ability kill',
#  'ability lie',
#  'ability listen',
#  'ability look',
#  'ability lost',
#  'ability make',
#  'ability making',
#  'ability manned',
#  'ability men',
#  'ability mind',
#  'ability moviemaking',
#  'ability mr',
#  'ability mystically',
#  'ability overcome',
#  'ability pack',
#  'ability parallels',
#  'ability pay',
#  'ability perfect',
#  'ability plastic',
#  'ability play',
#  'ability plug',
#  'ability precision',
#  'ability promotes',
#  'ability propel',
#  'ability pull',
#  'ability quickly',
#  'ability reasonably',
#  'ability reflect',
#  'ability relatively',
#  'ability rise',
#  'ability scare',
#  'ability sense',
#  'ability sentimental',
#  'ability sequoia',
#  'ability serve',
#  'ability set',
#  'ability shares',
#  'ability slow',
#  'ability spaceship',
#  'ability speak',
#  'ability stone',
#  'ability story',
#  'ability straight',
#  'ability strategize',
#  'ability supposedly',
#  'ability surprise',
#  'ability suspend',
#  'ability talk',
#  'ability tell',
#  'ability thankfully',
#  'ability things',
#  'ability think',
#  'ability time',
#  'ability trying',
#  'ability tune',
#  'ability understand',
#  'ability unfortunately',
#  'ability use',
#  'ability used',
#  'ability weave',
#  'ability whine',
#  'ability whoopi',
#  'ability woman',
#  'ability write',
#  'ability year',
#  'ability zeal',
#  'abject cruelty',
#  'abject humiliation',
#  'ablaze projector',
#  'ablaze referred',
#  'able access',
#  'able accessorize',
#  'able accomplish',
#  'able act',
#  'able add',
#  'able advance',
#  'able afford',
#  'able agreeable',
#  'able anticipate',
#  'able appreciate',
#  'able assasinate',
#  'able assists',
#  'able attention',
#  'able away',
#  'able baby',
#  'able bear',
#  'able beast',
#  'able bend',
#  'able best',
#  'able better',
#  'able blossom',
#  'able break',
#  'able bring',
#  'able burrow',
#  'able cake',
#  'able capitalize',
#  'able care',
#  'able carry',
#  'able catch',
#  'able certain',
#  'able change',
#  'able child',
#  'able choose',
#  'able city',
#  'able coast',
#  'able collate',
#  'able come',
#  'able communicate',
#  'able control',
#  'able convey',
#  'able convince',
#  'able convincingly',
#  'able craft',
#  'able create',
#  'able credit',
#  'able deadpan',
#  'able decipher',
#  'able define',
#  'able deliver',
#  'able demons',
#  'able demonstrate',
#  'able destroy',
#  'able detect',
#  'able determine',
#  'able difference',
#  'able differences',
#  'able direction',
#  'able discover',
#  'able disguise',
#  'able distinguish',
#  'able dreyfuss',
#  'able earth',
#  'able ease',
#  'able easily',
#  'able effectively',
#  'able elements',
#  'able elicit',
#  'able elude',
#  'able enjoy',
#  'able enliven',
#  'able enter',
#  'able entertain',
#  'able entire',
#  'able entrance',
#  'able escape',
#  'able excellent',
#  'able expand',
#  'able expose',
#  'able exude',
#  'able father',
#  'able feel',
#  'able fend',
#  'able fight',
#  'able film',
#  'able finds',
#  'able fly',
#  'able follow',
#  'able foresee',
#  'able forget',
#  'able forsee',
#  'able fresh',
#  'able fulfill',
#  'able gain',
#  'able gasoline',
#  'able gaze',
#  'able generate',
#  'able gladiator',
#  'able grasp',
#  'able guess',
#  'able gun',
#  'able handle',
#  'able happiness',
#  'able help',
#  'able highlight',
#  'able hold',
#  'able home',
#  'able hurt',
#  'able husband',
#  'able identify',
#  'able impossible',
#  'able intelligent',
#  'able introduce',
#  'able invigorate',
#  'able involve',
#  'able job',
#  'able join',
#  'able know',
#  'able laughs',
#  'able leap',
#  'able let',
#  'able life',
#  'able like',
#  'able lines',
#  'able locate',
#  'able look',
#  'able maintain',
#  'able make',
#  'able making',
#  'able meantime',
#  'able meet',
#  'able menacing',
#  'able momentarily',
#  'able money',
#  'able monster',
#  'able monty',
#  'able movie',
#  'able nab',
#  'able negotiate',
#  'able nephew',
#  'able new',
#  'able nice',
#  'able notice',
#  'able obtain',
#  'able opening',
#  'able overcome',
#  'able paid',
#  'able paint',
#  'able pass',
#  'able paying',
#  'able perfectly',
#  'able perform',
#  'able photograph',
#  'able picture',
#  'able pilot',
#  'able play',
#  'able plug',
#  'able portray',
#  'able predict',
#  'able predictable',
#  'able present',
#  'able proceed',
#  'able provide',
#  'able pull',
#  'able puppeteer',
#  'able quality',
#  'able rake',
#  'able rated',
#  'able reach',
#  'able real',
#  'able reap',
#  'able recognize',
#  'able reconcile',
#  'able relate',
#  'able remember',
#  'able rent',
#  'able repeat',
#  'able rescue',
#  'able resist',
#  'able reveal',
#  'able review',
#  'able right',
#  'able rise',
#  'able role',
#  'able round',
#  'able royer',
#  'able run',
#  'able satisfy',
#  'able save',
#  'able say',
#  'able send',
#  'able sense',
#  'able sensitive',
#  'able serve',
#  'able shallowly',
#  'able share',
#  'able shed',
#  'able silly',
#  'able sister',
#  'able sit',
#  'able slip',
#  'able somewhat',
#  'able sort',
#  'able spot',
#  'able stand',
#  'able steven',
#  'able stop',
#  'able stride',
#  'able successfully',
#  'able support',
#  'able suspend',
#  'able sustain',
#  'able talented',
#  'able talk',
#  'able taste',
#  'able tell',
#  'able things',
#  'able think',
#  'able thoroughly',
#  'able tolerate',
#  'able track',
#  'able transmit',
#  'able truly',
#  'able trust',
#  'able turn',
#  'able understand',
#  'able use',
#  'able using',
#  'able view',
#  'able walk',
#  'able watch',
#  'able way',
#  'able wear',
#  'able withhold',
#  'able withstand',
#  'able work',
#  'able writer',
#  'able writing',
#  'able zone',
#  'ably abetted',
#  'ably assumes',
#  'ably backed',
#  'ably built',
#  'ably captures',
#  'ably manages',
#  'ably shows',
#  'ably spooky',
#  'ably supported',
#  'abnormal daughter',
#  'abnormally reticent',
#  'abo actor',
#  'abo lively',
#  'abo needs',
#  'aboard boat',
#  'aboard comet',
#  'aboard delivers',
#  'aboard enemy',
#  'aboard futuristic',
#  'aboard illusions',
#  'aboard indianapolis',
#  'aboard inserts',
#  'aboard la',
#  'aboard lifeboat',
#  'aboard lifeboats',
#  'aboard looks',
#  'aboard mechanical',
#  'aboard medical',
#  'aboard nuclear',
#  'aboard patrick',
#  'aboard puts',
#  'aboard ride',
#  'aboard ship',
#  'aboard shuttle',
#  'aboard spaceship',
#  'aboard speeding',
#  'aboard sulaco',
#  'aboard supply',
#  'aboard swordfishing',
#  'aboard tatooed',
#  'aboard titanic',
#  'aboard vessel',
#  'abode action',
#  'abode broadcast',
#  'abode film',
#  'abode high',
#  'abode wall',
#  'abode wanting',
#  'abode williams',
#  'abolish child',
#  'abolish types',
#  'abolitionist spielberg',
#  'abolitionists hailed',
#  'abolitionists nigel',
#  'abolitionists regard',
#  'abolitionists stellan',
#  'abolitionists symbols',
#  'abolitionists theodore',
#  'abominable stick',
#  'abominable thriller',
#  'abomination film',
#  'abomination torturous',
#  'aborbed rose',
#  'aborginal friend',
#  'aboriginal people',
#  'aboriginal priest',
#  'aboriginal white',
#  'aboriginals handful',
#  'aboriginals people',
#  'aborigine manic',
#  'abort better',
#  'aborted pre',
#  'aborted wedding',
#  'abortion abortion',
#  'abortion causes',
#  'abortion clinic',
#  'abortion collection',
#  'abortion consulting',
#  'abortion fast',
#  'abortion hard',
#  'abortion illegal',
#  'abortion incest',
#  'abortion spent',
#  'abortionist unhappily',
#  'abortions high',
#  'abortions instead',
#  'abortive stab',
#  'aboslutely dreadful',
#  'abound appearance',
#  'abound castle',
#  'abound days',
#  'abound defy',
#  'abound differences',
#  'abound film',
#  'abound football',
#  'abound help',
#  'abound makes',
#  'abound moderately',
#  'abound ranging',
#  'abound rudy',
#  'abound wrong',
#  'abounded film',
#  'abounding goofiness',
#  'abounding news',
#  'abounds forced',
#  'abounds high',
#  'abounds including',
#  'abounds little',
#  'abouts movie',
#  'abraded rasp',
#  'abraham able',
#  'abraham aliens',
#  'abraham errors',
#  'abraham feels',
#  'abraham latest',
#  'abraham lincoln',
#  'abraham lost',
#  'abraham magnificient',
#  'abraham makes',
#  'abraham mess',
#  'abraham pursue',
#  'abraham stop',
#  'abraham stronger',
#  'abraham trying',
#  'abraham wing',
#  'abraham winner',
#  'abraham wished',
#  'abrahams baseketball',
#  'abrahams contributed',
#  'abrahams film',
#  'abrahams path',
#  'abrahams responsible',
#  'abrahams zucker',
#  'abrams adam',
#  'abrams directed',
#  'abrasive darkly',
#  'abrasive exhausting',
#  'abrasive father',
#  'abrasive good',
#  'abrasive mother',
#  'abrasive musical',
#  'abrasive personalities',
#  'abrasive self',
#  'abrasive standoffish',
#  'abreast latest',
#  'abril alain',
#  'abril pretty',
#  'abroad bening',
#  'abroad girlfriend',
#  'abroad responds',
#  'abroad slowly',
#  'abroad tumultuous',
#  'abrupt change',
#  'abrupt detour',
#  'abrupt end',
#  'abrupt halt',
#  'abrupt lighting',
#  'abrupt nosedive',
#  'abrupt story',
#  'abruptly car',
#  'abruptly changes',
#  'abruptly come',
#  'abruptly dropped',
#  'abruptly ending',
#  'abruptly resolution',
#  'abruptly says',
#  'abruptly shifts',
#  'abruptly starts',
#  'abruptly steps',
#  'abruptly switches',
#  'abruptly takes',
#  'abruptly whining',
#  'abs pearly',
#  'abs scamper',
#  'absconded luis',
#  'absence assigned',
#  'absence attend',
#  'absence boom',
#  'absence children',
#  'absence city',
#  'absence cuba',
#  'absence elizabeth',
#  'absence film',
#  'absence focus',
#  'absence forrester',
#  'absence hattie',
#  'absence kind',
#  'absence leaves',
#  'absence magnetism',
#  'absence major',
#  'absence monster',
#  'absence ready',
#  'absence real',
#  'absence rocky',
#  'absence screenwriter',
#  'absence single',
#  'absence suspense',
#  'absence thoroughly',
#  'absence toys',
#  'absence writer',
#  'absences include',
#  'absences maureen',
#  'absences wife',
#  'absense ballot',
#  'absent babe',
#  'absent comedy',
#  'absent draggy',
#  'absent ethics',
#  'absent feature',
#  'absent film',
#  'absent gladiator',
#  'absent institutions',
#  'absent mind',
#  'absent minded',
#  'absent mindedness',
#  'absent minute',
#  'absent occasional',
#  'absent parents',
#  'absent pictures',
#  'absent planet',
#  'absent popular',
#  'absent press',
#  'absent presumably',
#  'absent straightforward',
#  'absent sumptuous',
#  'absent thirteen',
#  'absent time',
#  'absentee father',
#  'absentee parents',
#  'absinthe bender',
#  'absinthe opium',
#  'absoloute masterpiece',
#  'absoltuely tension',
#  'absolut spinning',
#  'absolute assurance',
#  'absolute best',
#  'absolute catastrophe',
#  'absolute certainly',
#  'absolute constant',
#  'absolute dedication',
#  'absolute definitely',
#  'absolute delight',
#  'absolute disgust',
#  'absolute epitome',
#  'absolute faith',
#  'absolute finesse',
#  'absolute gems',
#  'absolute headache',
#  'absolute hell',
#  'absolute highlights',
#  'absolute innocence',
#  'absolute joy',
#  'absolute laughable',
#  'absolute lie',
#  'absolute loathe',
#  'absolute loyalty',
#  'absolute mess',
#  'absolute nothingness',
#  'absolute obscurity',
#  'absolute overkill',
#  'absolute power',
#  'absolute powerful',
#  'absolute scale',
#  'absolute sci',
#  'absolute truth',
#  'absolute yawn',
#  'absolutely actually',
#  'absolutely admit',
#  'absolutely adored',
#  'absolutely amazement',
#  'absolutely amazing',
#  'absolutely annoying',
#  'absolutely appears',
#  'absolutely arc',
#  'absolutely armageddon',
#  'absolutely attempt',
#  'absolutely badly',
#  'absolutely baseless',
#  'absolutely basis',
#  'absolutely beautiful',
#  'absolutely beautifully',
#  'absolutely begins',
#  'absolutely believable',
#  'absolutely blair',
#  'absolutely blown',
#  'absolutely breathtaking',
#  'absolutely brilliant',
#  'absolutely buddy',
#  'absolutely characters',
#  'absolutely cheerful',
#  'absolutely chilling',
#  'absolutely clearly',
#  'absolutely concern',
#  'absolutely connection',
#  'absolutely contempt',
#  'absolutely correct',
#  'absolutely crucial',
#  'absolutely degrees',
#  'absolutely depended',
#  'absolutely depth',
#  'absolutely deserved',
#  'absolutely dizzying',
#  'absolutely doubt',
#  'absolutely dreadful',
#  'absolutely effect',
#  'absolutely emotion',
#  'absolutely emotional',
#  'absolutely enchanting',
#  'absolutely encouraging',
#  'absolutely end',
#  'absolutely enter',
#  'absolutely entertaining',
#  'absolutely entrancing',
#  'absolutely fabricated',
#  'absolutely fabulous',
#  'absolutely fall',
#  'absolutely flies',
#  'absolutely footage',
#  'absolutely forced',
#  'absolutely game',
#  'absolutely ghastly',
#  'absolutely glorious',
#  'absolutely great',
#  'absolutely gripping',
#  'absolutely growing',
#  'absolutely guess',
#  'absolutely happened',
#  'absolutely hated',
#  'absolutely hilarious',
#  'absolutely horrible',
#  'absolutely hysterical',
#  'absolutely idea',
#  'absolutely illogical',
#  'absolutely impossible',
#  'absolutely incredible',
#  'absolutely infuriated',
#  'absolutely insight',
#  'absolutely intention',
#  'absolutely irresistible',
#  'absolutely jaw',
#  'absolutely knowledge',
#  'absolutely lack',
#  'absolutely lambert',
#  'absolutely leaving',
#  'absolutely levy',
#  'absolutely life',
#  'absolutely like',
#  'absolutely look',
#  'absolutely marry',
#  'absolutely marvel',
#  'absolutely masterful',
#  'absolutely masterpiece',
#  'absolutely maybe',
#  'absolutely mentioned',
#  'absolutely mesmerizing',
#  'absolutely message',
#  'absolutely minds',
#  'absolutely momentum',
#  'absolutely mystery',
#  'absolutely nails',
#  'absolutely necessary',
#  'absolutely new',
#  'absolutely notch',
#  'absolutely nudity',
#  'absolutely number',
#  'absolutely offensive',
#  'absolutely offer',
#  'absolutely original',
#  'absolutely painful',
#  'absolutely pathetic',
#  'absolutely perfect',
#  'absolutely personal',
#  'absolutely pizzazz',
#  'absolutely problem',
#  'absolutely purpose',
#  'absolutely question',
#  'absolutely reason',
#  'absolutely recommend',
#  'absolutely recurring',
#  'absolutely redeeming',
#  'absolutely remarkable',
#  'absolutely rest',
#  'absolutely ridiculous',
#  'absolutely right',
#  'absolutely romance',
#  'absolutely scary',
#  'absolutely scene',
#  'absolutely seen',
#  'absolutely sense',
#  'absolutely skill',
#  'absolutely speechless',
#  'absolutely stellar',
#  'absolutely stinks',
#  'absolutely story',
#  'absolutely stunning',
#  ...]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X_bi, y_bow, test_size= .2)
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X_train, y_train)#predictions
y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)#accuracy score 
train_pred_score = accuracy_score(y_train, y_train_pred)
test_pred_score = accuracy_score(y_test, y_test_pred)
print('Training Set Accuracy Score: \n', (100 * round(train_pred_score,4)))
print('Testing Set Accuracy Score: \n', (100 * round(test_pred_score,4)))
# Out:
# Training Set Accuracy Score:
#  100.0
# Testing Set Accuracy Score:
#  74.75

# %% [markdown]
# # On va maintenant essayer avec trigrammes et avec bigrammes + trigrammes

# %%
matrix3 = CountVectorizer(ngram_range=(3,3), 
# to use bigrams ngram_range=(2,2)
                           stop_words='english')

X_tri = matrix3.fit_transform(data['clean'])

# %%
matrix3.get_feature_names()
# Out:
# ['aa meetings gwennie',
#  'aa meetings pick',
#  'aa meetings shandling',
#  'aaa minor league',
#  'aaa team buzz',
#  'aaa team offers',
#  'aaaaaaaaah critique completely',
#  'aaaaaaaaah day sees',
#  'aaaaaaaahhhh plot grown',
#  'aaaaaah film savior',
#  'aaaahhhs wows let',
#  'aahs pixar work',
#  'aaliyah impressive expect',
#  'aaliyah shabby thought',
#  'aaliyah trish day',
#  'aalyah enchanting voice',
#  'aalyah mafia intrigues',
#  'aalyah magical voice',
#  'aamir khan muslim',
#  'aardman animation produced',
#  'aaron chuck norris',
#  'aaron convincing comes',
#  'aaron determined free',
#  'aaron eckhart amy',
#  'aaron eckhart ben',
#  'aaron eckhart jason',
#  'aaron eckhart lauren',
#  'aaron eckhart matt',
#  'aaron eckhart playing',
#  'aaron edward norton',
#  'aaron gets weirder',
#  'aaron moor tamora',
#  'aaron pearl harrison',
#  'aaron sandra bullock',
#  'aaron schneider reminiscient',
#  'aaron spelling couple',
#  'aaron spelling produced',
#  'aaron spelling territory',
#  'aaron steve martin',
#  'aaron williams secretly',
#  'aatish director guess',
#  'ab using technology',
#  'aback honesty sweetness',
#  'aback unusual ways',
#  'abandon alien years',
#  'abandon conviction sensitivity',
#  'abandon creation appearance',
#  'abandon depth favor',
#  'abandon despite patch',
#  'abandon educating break',
#  'abandon farm egg',
#  'abandon figured film',
#  'abandon film addresses',
#  'abandon final reel',
#  'abandon friends connect',
#  'abandon goal rebecca',
#  'abandon left liquor',
#  'abandon moment growing',
#  'abandon naturally like',
#  'abandon noise better',
#  'abandon preview press',
#  'abandon principle scientific',
#  'abandon rejecting natural',
#  'abandon rescue ship',
#  'abandon ship caught',
#  'abandon ship sends',
#  'abandon sure diluted',
#  'abandon trying say',
#  'abandon unique flashy',
#  'abandoned adopted danny',
#  'abandoned air force',
#  'abandoned altar day',
#  'abandoned altar years',
#  'abandoned beaten rescued',
#  'abandoned boredom finally',
#  'abandoned born decides',
#  'abandoned building surrounded',
#  'abandoned buildings turned',
#  'abandoned child desperately',
#  'abandoned church community',
#  'abandoned church dying',
#  'abandoned cruiser night',
#  'abandoned danvers state',
#  'abandoned david highly',
#  'abandoned father long',
#  'abandoned girlfriend years',
#  'abandoned highway rest',
#  'abandoned house soon',
#  'abandoned house strange',
#  'abandoned house street',
#  'abandoned house vampire',
#  'abandoned left shelf',
#  'abandoned literally groping',
#  'abandoned lose hand',
#  'abandoned lunatic asylum',
#  'abandoned luther forms',
#  'abandoned mansion end',
#  'abandoned mansion form',
#  'abandoned mining colony',
#  'abandoned novalee wal',
#  'abandoned owner grew',
#  'abandoned placed foster',
#  'abandoned planet nurse',
#  'abandoned prison turned',
#  'abandoned russian satellite',
#  'abandoned scrutinize contempt',
#  'abandoned sealed dark',
#  'abandoned segments drawing',
#  'abandoned shed forces',
#  'abandoned signature style',
#  'abandoned singer alcoholic',
#  'abandoned spaceship ensues',
#  'abandoned spouses molly',
#  'abandoned steelworks provides',
#  'abandoned theater decrepit',
#  'abandoned throws lingering',
#  'abandoned warehouse frank',
#  'abandoned warehouse wayne',
#  'abandoned wing mental',
#  'abandoning facial contortions',
#  'abandoning project called',
#  'abandonment alcoholic mother',
#  'abandonment hope david',
#  'abandonment paradise exactly',
#  'abandonment source material',
#  'abandons angry mob',
#  'abandons climactic flurry',
#  'abandons english captors',
#  'abandons hang popular',
#  'abandons maroon stretch',
#  'abandons old life',
#  'abandons planet earth',
#  'abandons political aspect',
#  'abating time soon',
#  'abba music fantasies',
#  'abba tunes virtually',
#  'abbe coulmier phoenix',
#  'abbe handsome charming',
#  'abbe lusts madeleine',
#  'abberation continues lightning',
#  'abberline johnny depp',
#  'abberline widower prophetic',
#  'abbots circle friends',
#  'abbott jay comic',
#  'abbotts eventually sets',
#  'abbreviated bedhopping montage',
#  'abby asks big',
#  'abby asks father',
#  'abby assuming role',
#  'abby frances mcdormand',
#  'abby furthering relationship',
#  'abby knows body',
#  'abby kohn marc',
#  'abby meet abby',
#  'abby mistakes attacker',
#  'abby nia long',
#  'abby olivia williams',
#  'abby relates like',
#  'abby talk radio',
#  'abby tells burp',
#  'abby thrown company',
#  'abc fox mourn',
#  'abc monday night',
#  'abc sabrina teenage',
#  'abc wonderful world',
#  'abdomen alien baby',
#  'abdomen sloppy gory',
#  'abducted brought believe',
#  'abducted dr kate',
#  'abducted mctiernan wakes',
#  'abducted suspected culprit',
#  'abducted tortured sinister',
#  'abductees abducted dr',
#  'abduction meantime scientists',
#  'abduction save kidnapped',
#  'abduction scenarios known',
#  'abduction scene suspenseful',
#  'abduction young child',
#  'abductions genetic hybridization',
#  'abductions sad actually',
#  'abdul jabbar frank',
#  'abe handling godzilla',
#  'abe lincoln beard',
#  'abe petrovsky landau',
#  'abel ferrara dark',
#  'abel ferrara movie',
#  'abel ferrara worse',
#  'abel ferrera china',
#  'abel prosecutes murder',
#  'aberdeen able coast',
#  'aberdeen differences way',
#  'aberdeen earlier film',
#  'aberdeen half ambitious',
#  'aberdeen jean bruno',
#  'aberdeen know weak',
#  'aberdeen rampling luminous',
#  'aberdeen scotland automobile',
#  'aberdeen sentimental painfully',
#  'aberdeen strives focusing',
#  'aberration film filled',
#  'aberration incipient creature',
#  'abetted director patrick',
#  'abetted wonderfully demented',
#  'abetting criminals sentenced',
#  'abetting team shady',
#  'abhorrence rise nazism',
#  'abhorrent blatantly unlikable',
#  'abhorrent picture superficial',
#  'abider tolerance breaks',
#  'abides catholic principle',
#  'abiding ethnically stereotyped',
#  'abigail alarming synchronicity',
#  'abigail consistent mood',
#  'abigail obsession unfortunately',
#  'abigail passion sets',
#  'abigail seizes opportunity',
#  'abigail supposedly revels',
#  'abigail winona ryder',
#  'abiility thanks years',
#  'abilities acting leaves',
#  'abilities ahem save',
#  'abilities backup john',
#  'abilities best biggest',
#  'abilities center movie',
#  'abilities challenged way',
#  'abilities clumsy film',
#  'abilities consequently easy',
#  'abilities create entei',
#  'abilities differ actors',
#  'abilities disclosed braveheart',
#  'abilities disney studio',
#  'abilities displays gift',
#  'abilities emotionally unconvincing',
#  'abilities end really',
#  'abilities evident boyish',
#  'abilities hard people',
#  'abilities intelligent reasonable',
#  'abilities leads dunst',
#  'abilities lee great',
#  'abilities letdown black',
#  'abilities likely chosen',
#  'abilities limited best',
#  'abilities little league',
#  'abilities look good',
#  'abilities makes owner',
#  'abilities mia kirshner',
#  'abilities needs survive',
#  'abilities order best',
#  'abilities past sorely',
#  'abilities performances donaldson',
#  'abilities reap vengeance',
#  'abilities sets complete',
#  'abilities shine unlike',
#  'abilities spent rest',
#  'abilities start brutal',
#  'abilities story revolves',
#  'abilities strangers help',
#  'abilities support niro',
#  'abilities tom welles',
#  'abilities trailer movie',
#  'abilities tries vain',
#  'abilities unown bring',
#  'abilities uses land',
#  'abilities usual lackluster',
#  'abilities wonderful film',
#  'ability actors especially',
#  'ability actress shame',
#  'ability age problems',
#  'ability allow killer',
#  'ability appreciate life',
#  'ability away film',
#  'ability blow powerful',
#  'ability bring circle',
#  'ability carry film',
#  'ability catherine zeta',
#  'ability challenge world',
#  'ability choose fate',
#  'ability chuck norris',
#  'ability cliche cartoony',
#  'ability comparable steven',
#  'ability conceive simple',
#  'ability control stone',
#  'ability convey concealed',
#  'ability convey feeling',
#  'ability create intoxicating',
#  'ability create ongoing',
#  'ability create sound',
#  'ability create villain',
#  'ability daphne rubin',
#  'ability decent movie',
#  'ability different races',
#  'ability direct amazing',
#  'ability disappointed fact',
#  'ability discern right',
#  'ability drama doubted',
#  'ability echo gunshot',
#  'ability enhance movie',
#  'ability enjoyed success',
#  'ability enraptured extension',
#  'ability entertain convinces',
#  'ability establish mood',
#  'ability exception wonderful',
#  'ability excursions fun',
#  'ability experience playing',
#  'ability extract gorgeous',
#  'ability far underrated',
#  'ability fast forward',
#  'ability fly wrong',
#  'ability fold time',
#  'ability forge independent',
#  'ability gain erection',
#  'ability going characters',
#  'ability got post',
#  'ability handle suspense',
#  'ability heal unlike',
#  'ability hollow man',
#  'ability hot collar',
#  'ability impress audience',
#  'ability invasion partly',
#  'ability isabella cruz',
#  'ability jaw dropping',
#  'ability kill people',
#  'ability lie nearly',
#  'ability listen people',
#  'ability look drop',
#  'ability look like',
#  'ability lost details',
#  'ability make distinction',
#  'ability make look',
#  'ability make old',
#  'ability make routine',
#  'ability make seen',
#  'ability make watch',
#  'ability making character',
#  'ability manned aircraft',
#  'ability men playing',
#  'ability men survived',
#  'ability mind meld',
#  'ability moviemaking film',
#  'ability mr heston',
#  'ability mystically manifest',
#  'ability overcome bad',
#  'ability pack belongings',
#  'ability parallels character',
#  'ability pay way',
#  'ability perfect people',
#  'ability plastic facial',
#  'ability play good',
#  'ability play nuances',
#  'ability play uppity',
#  'ability plug brain',
#  'ability precision romeo',
#  'ability promotes sergeant',
#  'ability propel assailant',
#  'ability pull character',
#  'ability quickly deliver',
#  'ability reasonably expect',
#  'ability reflect norms',
#  'ability relatively ordinary',
#  'ability rise inept',
#  'ability scare wits',
#  'ability sense experienced',
#  'ability sentimental turning',
#  'ability sequoia kurtwood',
#  'ability serve long',
#  'ability set scam',
#  'ability shares picard',
#  'ability slow time',
#  'ability spaceship kind',
#  'ability speak different',
#  'ability speak run',
#  'ability stone works',
#  'ability story entertain',
#  'ability straight face',
#  'ability strategize cornered',
#  'ability supposedly time',
#  'ability surprise frighten',
#  'ability suspend difficult',
#  'ability talk ferret',
#  'ability tell epic',
#  'ability tell good',
#  'ability tell story',
#  'ability thankfully sanity',
#  'ability things mind',
#  'ability think ben',
#  'ability think entertain',
#  'ability time scene',
#  'ability trying desperately',
#  'ability tune warp',
#  'ability understand animals',
#  'ability unfortunately obscured',
#  'ability use skin',
#  'ability used particular',
#  'ability weave various',
#  'ability whine irritate',
#  'ability whoopi goldberg',
#  'ability woman couple',
#  'ability write direct',
#  'ability year old',
#  'ability zeal sniff',
#  'abject cruelty truman',
#  'abject humiliation american',
#  'ablaze projector vote',
#  'ablaze referred barbecue',
#  'able access obviously',
#  'able accessorize banter',
#  'able accomplish superhuman',
#  'able act like',
#  'able add little',
#  'able advance screening',
#  'able afford gratuities',
#  'able agreeable unlike',
#  'able anticipate major',
#  'able appreciate beauty',
#  'able appreciate distance',
#  'able appreciate film',
#  'able assasinate person',
#  'able assists editors',
#  'able attention butt',
#  'able away jeffries',
#  'able baby societal',
#  'able bear children',
#  'able beast people',
#  'able bend women',
#  'able best dreamworks',
#  'able best thing',
#  'able better performance',
#  'able blossom fully',
#  'able break bitterness',
#  'able break medieval',
#  'able bring feral',
#  'able bring sense',
#  'able bring tears',
#  'able burrow loose',
#  'able cake eat',
#  'able capitalize success',
#  'able care pain',
#  'able care scenes',
#  'able carry commercial',
#  'able carry film',
#  'able catch killer',
#  'able certain memories',
#  'able change natural',
#  'able child divorce',
#  'able child hasidim',
#  'able choose oneself',
#  'able city feeling',
#  'able city undetected',
#  'able coast performances',
#  'able collate sleazy',
#  'able come senses',
#  'able come years',
#  'able communicate assistant',
#  'able communicate dead',
#  'able communicate men',
#  'able control long',
#  'able convey horror',
#  'able convey pretty',
#  'able convince friends',
#  'able convincingly portray',
#  'able craft original',
#  'able create character',
#  'able create complete',
#  'able create effectively',
#  'able create faster',
#  'able create lot',
#  'able create lush',
#  'able create new',
#  'able create robotics',
#  'able create sense',
#  'able create worm',
#  'able credit producing',
#  'able deadpan way',
#  'able decipher dialogue',
#  'able define realities',
#  'able deliver lines',
#  'able demons rest',
#  'able demonstrate recognition',
#  'able destroy master',
#  'able detect hole',
#  'able determine correct',
#  'able determine quality',
#  'able determine spike',
#  'able difference real',
#  'able differences work',
#  'able direction engaging',
#  'able discover advancements',
#  'able disguise bad',
#  'able distinguish character',
#  'able dreyfuss dreyfuss',
#  'able earth failed',
#  'able ease pain',
#  'able easily suspend',
#  'able effectively work',
#  'able elements like',
#  'able elicit film',
#  'able elude doc',
#  'able enjoy complexity',
#  'able enjoy new',
#  'able enliven movie',
#  'able enter situation',
#  'able entertain movie',
#  'able entire cities',
#  'able entrance viewer',
#  'able escape death',
#  'able escape executioners',
#  'able escape separated',
#  'able excellent film',
#  'able expand develop',
#  'able expand saw',
#  'able expose romantic',
#  'able exude aura',
#  'able father information',
#  'able feel edge',
#  'able fend thread',
#  'able fight like',
#  'able film consistently',
#  'able film seldom',
#  'able finds left',
#  'able fly broom',
#  'able fly leave',
#  'able follow excellent',
#  'able foresee kind',
#  'able forget soap',
#  'able forsee late',
#  'able fresh laughs',
#  'able fulfill wish',
#  'able gain upper',
#  'able gasoline engines',
#  'able gaze flowers',
#  'able generate type',
#  'able gladiator soldier',
#  'able grasp characters',
#  'able guess identity',
#  'able gun enjoyable',
#  'able handle double',
#  'able handle horribly',
#  'able handle variety',
#  'able happiness life',
#  'able help falling',
#  'able highlight large',
#  'able hold course',
#  'able home better',
#  'able hurt close',
#  'able husband little',
#  'able identify care',
#  'able identify eve',
#  'able identify tarzan',
#  'able impossible reviewers',
#  'able intelligent flying',
#  'able introduce new',
#  'able invigorate hackneyed',
#  'able involve basic',
#  'able job guy',
#  'able join rest',
#  'able know characters',
#  'able know coming',
#  'able laughs going',
#  'able leap atop',
#  'able let hang',
#  'able life julie',
#  'able like primary',
#  'able lines nice',
#  'able locate albania',
#  'able locate stargher',
#  'able look horseracing',
#  'able look like',
#  'able maintain care',
#  'able maintain required',
#  'able maintain viewer',
#  'able make comedy',
#  'able make comfortable',
#  'able make film',
#  'able make heart',
#  'able make informed',
#  'able make innocuous',
#  'able make logjams',
#  'able make proper',
#  'able make sense',
#  'able make sick',
#  'able make tense',
#  'able make think',
#  'able make tough',
#  'able making goes',
#  'able meantime upstate',
#  'able meet famed',
#  'able menacing fact',
#  'able momentarily mind',
#  'able money sitting',
#  'able monster corner',
#  'able monty said',
#  'able movie free',
#  'able nab oscar',
#  'able negotiate way',
#  'able nephew contact',
#  'able new direction',
#  'able nice job',
#  'able notice case',
#  'able obtain money',
#  'able opening half',
#  'able overcome proud',
#  'able paid scam',
#  'able paint colors',
#  'able pass christina',
#  'able pass year',
#  'able paying production',
#  'able perfectly portray',
#  'able perform duties',
#  'able perform funny',
#  'able photograph intense',
#  'able picture non',
#  'able pilot west',
#  'able play mean',
#  'able plug play',
#  'able portray angst',
#  'able predict action',
#  'able predict catastrophic',
#  'able predict happen',
#  'able predict plot',
#  'able predictable element',
#  'able present shocking',
#  'able proceed resort',
#  'able provide children',
#  'able pull allow',
#  'able pull like',
#  'able pull particular',
#  'able puppeteer arms',
#  'able quality high',
#  'able rake lawn',
#  'able rated film',
#  'able reach anemic',
#  'able reach upwards',
#  'able real time',
#  'able reap similar',
#  'able recognize mother',
#  'able recognize things',
#  'able reconcile script',
#  'able relate behaviors',
#  'able remember actress',
#  'able remember processes',
#  'able rent movie',
#  'able repeat words',
#  'able rescue movie',
#  'able resist charms',
#  'able resist seeing',
#  'able reveal emotions',
#  'able review ages',
#  'able right film',
#  'able right guy',
#  'able rise level',
#  'able role like',
#  'able role taking',
#  'able role truman',
#  'able round exactly',
#  'able royer collard',
#  'able run gamut',
#  'able satisfy variety',
#  'able satisfy wife',
#  'able save chore',
#  'able save film',
#  'able say assault',
#  'able say book',
#  'able say creature',
#  'able say let',
#  'able say lived',
#  'able say van',
#  'able say way',
#  'able send final',
#  'able sense thinking',
#  'able sensitive vulnerable',
#  'able serve exceptional',
#  'able shallowly laugh',
#  'able share rush',
#  'able shed comedy',
#  'able silly situations',
#  'able sister needs',
#  'able sit critical',
#  'able sit reviews',
#  'able slip character',
#  'able somewhat come',
#  'able sort life',
#  'able spot summer',
#  'able stand ensemble',
#  'able steven ends',
#  'able stop assassination',
#  'able stride like',
#  'able successfully navigate',
#  'able support complex',
#  'able suspend disbelief',
#  'able sustain life',
#  'able talented cast',
#  'able talk god',
#  'able talk queen',
#  'able talk slide',
#  'able talk suddenly',
#  'able talk way',
#  'able taste food',
#  'able tell characters',
#  'able tell digital',
#  'able tell happen',
#  'able tell story',
#  'able things acting',
#  'able things hate',
#  'able think feet',
#  'able think remember',
#  'able thoroughly enjoy',
#  'able tolerate story',
#  'able track really',
#  'able track simon',
#  'able transmit garbled',
#  'able truly enjoy',
#  'able trust makes',
#  'able turn bianca',
#  'able turn nice',
#  'able turn tv',
#  'able understand movie',
#  'able understand perfect',
#  'able understand simple',
#  'able use assistance',
#  'able use senses',
#  'able using fake',
#  'able view film',
#  'able walk sunlight',
#  'able watch film',
#  'able watch movie',
#  'able watch sure',
#  'able way watching',
#  'able wear transvestites',
#  'able withhold greater',
#  'able withstand great',
#  'able work confines',
#  'able work fix',
#  'able writer mario',
#  'able writing directing',
#  'able zone zero',
#  'ably abetted wonderfully',
#  'ably assumes various',
#  'ably backed sly',
#  'ably built bulk',
#  'ably captures dreariness',
#  'ably manages avoid',
#  'ably shows size',
#  'ably spooky house',
#  'ably supported best',
#  'ably supported selected',
#  'ably supported strong',
#  'abnormal daughter fantasy',
#  'abnormally reticent hiding',
#  'abo actor close',
#  'abo lively lass',
#  'abo needs ditzy',
#  'aboard boat leaving',
#  'aboard comet bombing',
#  'aboard delivers rocket',
#  'aboard enemy waters',
#  'aboard futuristic looking',
#  'aboard illusions set',
#  'aboard indianapolis navy',
#  'aboard inserts message',
#  'aboard la amistad',
#  'aboard lifeboat hear',
#  'aboard lifeboats way',
#  'aboard looks like',
#  'aboard mechanical tarantula',
#  'aboard medical space',
#  'aboard nuclear submarines',
#  'aboard patrick ross',
#  'aboard puts storage',
#  'aboard ride fran',
#  'aboard ship beautiful',
#  'aboard ship happened',
#  'aboard ship looking',
#  'aboard ship prior',
#  'aboard shuttle slime',
#  'aboard spaceship crew',
#  'aboard speeding coach',
#  'aboard sulaco facehugger',
#  'aboard supply vessel',
#  'aboard swordfishing boat',
#  'aboard tatooed penis',
#  'aboard titanic poker',
#  'aboard vessel aliens',
#  'abode action sequence',
#  'abode broadcast continent',
#  'abode film hits',
#  'abode high mountains',
#  'abode wall jumps',
#  'abode wanting stay',
#  'abode williams excellent',
#  'abolish child labor',
#  'abolish types horrors',
#  'abolitionist spielberg finest',
#  'abolitionists hailed boston',
#  'abolitionists nigel hawthorne',
#  'abolitionists regard africans',
#  'abolitionists stellan skaarsgard',
#  'abolitionists symbols humans',
#  'abolitionists theodore joadson',
#  'abominable stick sole',
#  'abominable thriller julie',
#  'abomination film entirely',
#  'abomination torturous sit',
#  'aborbed rose goes',
#  'aborginal friend tony',
#  'aboriginal people line',
#  'aboriginal priest best',
#  'aboriginal white fellas',
#  'aboriginals handful white',
#  'aboriginals people proud',
#  'aborigine manic russian',
#  'abort better strap',
#  'aborted pre release',
#  'aborted wedding appealing',
#  'abortion abortion illegal',
#  'abortion causes emotion',
#  'abortion clinic day',
#  'abortion clinic worker',
#  'abortion collection half',
#  'abortion consulting doubt',
#  'abortion fast times',
#  'abortion hard imagine',
#  'abortion illegal doctor',
#  'abortion incest prominent',
#  'abortion spent time',
#  'abortionist unhappily pregnant',
#  'abortions high fatality',
#  'abortions instead wondering',
#  'abortive stab half',
#  'aboslutely dreadful indien',
#  'abound appearance role',
#  'abound castle film',
#  'abound days cloudy',
#  'abound defy logic',
#  'abound differences director',
#  'abound film mystical',
#  'abound football crazy',
#  'abound help trigger',
#  'abound makes zipper',
#  'abound moderately entertaining',
#  'abound ranging secret',
#  'abound rudy shift',
#  'abound wrong cast',
#  'abounded film humour',
#  'abounding goofiness adult',
#  'abounding news lately',
#  'abounds forced deal',
#  'abounds high production',
#  'abounds including slapstick',
#  'abounds little revelations',
#  'abouts movie great',
#  'abraded rasp smokes',
#  'abraham able destroy',
#  'abraham aliens number',
#  'abraham errors ways',
#  'abraham feels waves',
#  'abraham latest film',
#  'abraham lincoln emerson',
#  'abraham lost job',
#  'abraham magnificient salieri',
#  'abraham makes perfect',
#  'abraham mess son',
#  'abraham pursue sport',
#  'abraham stop performing',
#  'abraham stronger power',
#  'abraham trying colonists',
#  'abraham wing apprentice',
#  'abraham winner academy',
#  'abraham wished follow',
#  'abrahams baseketball proft',
#  'abrahams contributed gut',
#  'abrahams film spoofs',
#  'abrahams path times',
#  'abrahams responsible hits',
#  'abrahams zucker film',
#  'abrahams zucker team',
#  'abrams adam larson',
#  'abrams directed michael',
#  'abrasive darkly humorous',
#  'abrasive exhausting watch',
#  'abrasive father authoritatively',
#  'abrasive good teacher',
#  'abrasive mother law',
#  'abrasive musical score',
#  'abrasive personalities result',
#  'abrasive self consciously',
#  'abrasive standoffish try',
#  'abreast latest developments',
#  'abril alain chabat',
#  'abril pretty likable',
#  'abroad bening character',
#  'abroad girlfriend stifler',
#  'abroad responds retaliating',
#  'abroad slowly surely',
#  'abroad tumultuous little',
#  'abrupt change reeks',
#  'abrupt detour supernatural',
#  'abrupt end applaud',
#  'abrupt end refused',
#  'abrupt halt actually',
#  'abrupt halt endurance',
#  'abrupt lighting poor',
#  'abrupt nosedive eastwood',
#  'abrupt story earth',
#  'abruptly car malfunctions',
#  'abruptly changes story',
#  'abruptly come helen',
#  'abruptly dropped brought',
#  'abruptly ending susceptible',
#  'abruptly resolution minutes',
#  'abruptly says oh',
#  'abruptly shifts setting',
#  'abruptly starts murdering',
#  'abruptly steps window',
#  'abruptly switches gears',
#  'abruptly takes friend',
#  'abruptly whining cause',
#  'abs pearly white',
#  'abs scamper woman',
#  'absconded luis fortune',
#  'absence assigned buzz',
#  'absence attend marriage',
#  'absence boom mics',
#  'absence children picking',
#  'absence city harlem',
#  'absence cuba gooding',
#  'absence elizabeth hurley',
#  'absence film unforgivable',
#  'absence focus leave',
#  'absence forrester sidekick',
#  'absence hattie jacques',
#  'absence kind emotional',
#  'absence leaves terrible',
#  'absence magnetism meaning',
#  'absence major stars',
#  'absence monster infinitely',
#  'absence ready laughing',
#  'absence real human',
#  'absence rocky turns',
#  'absence screenwriter kevin',
#  'absence single solitary',
#  'absence suspense film',
#  'absence thoroughly charming',
#  'absence toys scamper',
#  'absence writer kevin',
#  'absences include tom',
#  'absences maureen attacked',
#  'absences wife fears',
#  'absense ballot complete',
#  'absent babe pig',
#  'absent comedy acting',
#  'absent draggy exercise',
#  'absent ethics start',
#  'absent feature films',
#  'absent film relegating',
#  'absent gladiator begins',
#  'absent institutions referenced',
#  'absent mind professor',
#  'absent minded absent',
#  'absent minded fact',
#  'absent minded mindless',
#  'absent minded professor',
#  'absent minded professory',
#  'absent minded way',
#  'absent mindedness forgotten',
#  'absent mindedness proffessor',
#  'absent minute running',
#  'absent occasional references',
#  'absent parents join',
#  'absent pictures true',
#  'absent planet suppose',
#  'absent popular boy',
#  'absent press kit',
#  'absent presumably assumption',
#  'absent straightforward chronology',
#  'absent sumptuous tableware',
#  'absent thirteen years',
#  'absent time regarded',
#  'absentee father convinced',
#  'absentee parents merciless',
#  'absinthe bender alternative',
#  'absinthe opium arriving',
#  'absoloute masterpiece eqsuisite',
#  'absoltuely tension drawn',
#  'absolut spinning jiggling',
#  'absolute assurance film',
#  'absolute best level',
#  'absolute catastrophe director',
#  'absolute catastrophe watching',
#  'absolute certainly given',
#  'absolute constant stream',
#  'absolute dedication ministry',
#  'absolute definitely ticket',
#  'absolute delight stealing',
#  'absolute disgust frustration',
#  'absolute epitome sanctimonious',
#  'absolute faith soldiers',
#  'absolute finesse director',
#  'absolute gems example',
#  'absolute headache shot',
#  'absolute hell soldiers',
#  ...]

# %%
X_tri
# Out:
# <2000x600314 sparse matrix of type '<class 'numpy.int64'>'
# 	with 613942 stored elements in Compressed Sparse Row format>

# %%
from scipy.sparse import hstack
X_multi = hstack((X_bi, X_tri))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X_tri, y_bow, test_size= .2)
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X_train, y_train)#predictions
y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)#accuracy score 
train_pred_score = accuracy_score(y_train, y_train_pred)
test_pred_score = accuracy_score(y_test, y_test_pred)
print('Training Set Accuracy Score: \n', (100 * round(train_pred_score,4)))
print('Testing Set Accuracy Score: \n', (100 * round(test_pred_score,4)))
# Out:
# Training Set Accuracy Score:
#  100.0
# Testing Set Accuracy Score:
#  52.75

# %% [markdown]
# Résultat : Bigramme etait mieux

# %% [markdown]
# # On va essayer un  autre classifieur:

# %%
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)#accuracy score 
train_pred_score = accuracy_score(y_train, y_train_pred)
test_pred_score = accuracy_score(y_test, y_test_pred)
print('Training Set Accuracy Score: \n', (100 * round(train_pred_score,4)))
print('Testing Set Accuracy Score: \n', (100 * round(test_pred_score,4)))
# Out:
# Training Set Accuracy Score:
#  100.0
# Testing Set Accuracy Score:
#  75.25

# %%
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='rbf',gamma=0.5) # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)#accuracy score 
train_pred_score = accuracy_score(y_train, y_train_pred)
test_pred_score = accuracy_score(y_test, y_test_pred)
print('Training Set Accuracy Score: \n', (100 * round(train_pred_score,4)))
print('Testing Set Accuracy Score: \n', (100 * round(test_pred_score,4)))
# Out:
# Training Set Accuracy Score:
#  100.0
# Testing Set Accuracy Score:
#  47.75

# %%
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='poly') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)#accuracy score 
train_pred_score = accuracy_score(y_train, y_train_pred)
test_pred_score = accuracy_score(y_test, y_test_pred)
print('Training Set Accuracy Score: \n', (100 * round(train_pred_score,4)))
print('Testing Set Accuracy Score: \n', (100 * round(test_pred_score,4)))
# Out:
# Training Set Accuracy Score:
#  94.31
# Testing Set Accuracy Score:
#  52.5
